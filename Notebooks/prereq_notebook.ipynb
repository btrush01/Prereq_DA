# %%
print("Here's some text to show I can print to the screen.")
# Out:
# Here's a line to show I can code. I hope to learn the skills I need to break out into the technical world.
# My last career path didn't work out, and at 34 I'm concerned about my future.
# I'm especially interested to learn what my mentors did to ''make it''. I could use some of that myself.

# %%
print("This semester I hope to learn the skills I need to break out into the technical world.")
print("My last career path (teacher) didn't work out, and at 34 I'm concerned about my future.")
print("I'm especially interested to learn what my mentors did to ''make it''. I could use some of that wisdom right now!")
